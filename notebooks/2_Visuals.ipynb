# %% [markdown]
# Data Loadaing

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from src.config.paths import RAW_DATA,VISUAL

# %%
df = pd.read_csv(RAW_DATA)
sns.set_theme(style='darkgrid')

# %% [markdown]
# # Age

# %%
sns.histplot(data=df , x='age')
plt.title("Age Frequency")
plt.savefig(VISUAL/'age/age-freq.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
sns.lineplot(data=df,x='age',y='bmi',hue='sex')
plt.title("BMI To Age")
plt.savefig(VISUAL/'age/age-bmi.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
sns.boxplot(data=df,x='age')
plt.title("Medians")
plt.savefig(VISUAL/'age/age-boxplot.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
sns.lineplot(data=df,x='age',y='charges',hue='sex')
plt.title("Charges To Age")
plt.savefig(VISUAL/'age-charges.png',dpi=300,bbox_inches='tight')
plt.show()

# %% [markdown]
# # BMI

# %%
sns.histplot(data=df,x='bmi')
plt.title("BMI Frequency")
plt.savefig(VISUAL/'bmi/bmi-freq.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
sns.boxplot(data=df,x='bmi')
plt.title("Medians")
plt.savefig(VISUAL/'bmi/bmi-boxplot.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
sns.scatterplot(data=df,x='bmi',y='charges',hue='sex')
plt.title("Charges To BMI")
plt.savefig(VISUAL/'bmi/bmi-charges.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
sns.lineplot(data=df,x='bmi',y='charges',hue='sex')
plt.title("Charges To BMI")
plt.savefig(VISUAL/'bmi/bmi-charges-line.png',dpi=300,bbox_inches='tight')
plt.show()

# %% [markdown]
# # Sex

# %%
sns.countplot(data=df,x='sex')
plt.title("Sex Frequency")
plt.savefig(VISUAL/'sex/sex-freq.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
sns.barplot(data=df,x='sex',y='charges')
plt.savefig(VISUAL/'sex/sex-confidence.png',dpi=300,bbox_inches='tight')
plt.title("Confidence with Charges")
plt.show()

# %%
sns.violinplot(data=df,x='sex',y='charges')
plt.title("Charges To Sex")
plt.savefig(VISUAL/'sex/sex-charges-violin.png',dpi=300,bbox_inches='tight')
plt.show()

# %% [markdown]
# # Children

# %%
sns.histplot(data=df,x='children')
plt.title("Children Frequency")
plt.savefig(VISUAL/'children/child-freq.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
sns.lineplot(data=df,x='children',y='charges')
plt.title("Charges To Children")
plt.savefig(VISUAL/'children/child-charges-line.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
sns.lineplot(data=df,x='children',y='charges',hue='sex')
plt.title("Charges To Children")
plt.savefig(VISUAL/'children/child-charges-sex-line.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
sns.boxplot(data=df,x='children')
plt.title("Medians")
plt.savefig(VISUAL/'children/child-boxplot.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
sns.violinplot(data=df,x='children',y='charges')
plt.show()

# %% [markdown]
# # Smoker

# %%
sns.countplot(data=df,x='smoker',hue='sex')
plt.title("Smoker Frequency")
plt.savefig(VISUAL/'smoker/smoker-sex-freq.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
sns.countplot(data=df,x='smoker',hue='children')
plt.title("Smoker Frequency")
plt.savefig(VISUAL/'smoker/smoker-children-freq.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
sns.barplot(data=df,x='smoker',y='charges',hue='sex')
plt.savefig(VISUAL/'smoker/smoker-charges-confidence.png',dpi=300,bbox_inches='tight')
plt.title("Confidence With Charges")
plt.show()

# %%
sns.violinplot(data=df,x='smoker',y='charges',hue="sex")
plt.savefig(VISUAL/'smoker/smoker-charges-sex-violin.png',dpi=300,bbox_inches='tight')
plt.title("Charges To Smoker")
plt.show()

# %% [markdown]
# # Region

# %%
sns.countplot(data=df,x='region')
plt.title("Region Frequency")
plt.savefig(VISUAL/'region/region-freq.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
sns.countplot(data=df,x='region',hue='sex')
plt.title("Region Frequency")
plt.savefig(VISUAL/'region/region-sex-freq.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
sns.violinplot(data=df,x='region',y='charges')
plt.title("Charges To Region")
plt.savefig(VISUAL/'region/region-charges-violin.png',dpi=300,bbox_inches='tight')
plt.show()

# %% [markdown]
# # Charges

# %%
sns.histplot(data=df,x='charges')
plt.title("Charges Frequency")
plt.savefig(VISUAL/'charges/charges-freq.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
sns.boxplot(data=df,x='charges')
plt.title("Medians")
plt.savefig(VISUAL/'charges/charges-boxplot.png',dpi=300,bbox_inches='tight')
plt.show()

# %% [markdown]
# # Correlation

# %%
# Select only numerical columns
num_df = df.select_dtypes(include=['int64', 'float64'])

# Compute correlation
corr = num_df.corr()

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Numerical Columns")
plt.show()
